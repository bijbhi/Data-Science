# %% [markdown]
# <a href="https://colab.research.google.com/github/bijbhi/Data-Science/blob/bijbhi-patch-1/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/nyc_taxis.csv")

# %%
df
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# ...            ...           ...         ...               ...          ...
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
# ...

# %%
taxi = np.genfromtxt("/content/drive/MyDrive/Colab Notebooks/nyc_taxis.csv",delimiter=",",skip_header=True)

# %%
df["speed_1"] = df["trip_distance"] /((df["trip_length"])/3600)

# %%
df
# Out:
#        pickup_year  pickup_month  pickup_day  pickup_dayofweek  pickup_time  \
# 0             2016             1           1                 5            0
# 1             2016             1           1                 5            0
# 2             2016             1           1                 5            0
# 3             2016             1           1                 5            0
# 4             2016             1           1                 5            0
# ...            ...           ...         ...               ...          ...
# 89555         2016             6          30                 4            5
# 89556         2016             6          30                 4            5
# 89557         2016             6          30                 4            5
# 89558         2016             6          30                 4            5
# 89559         2016             6          30                 4            5
#
# ...

# %%
mean_speed_1 = speed.mean()
print(mean_speed_1)
# Out:
# 32.24258580925637

# %%
speed = taxi[:,7]/ (taxi[:,8]/3600)

# %%
speed
# Out:
# array([37.11340206, 38.58157895, 31.27222982, ..., 22.29907867,
#        42.41551247, 36.90473407])

# %%
mean_speed = speed.mean()
print(mean_speed)
# Out:
# 32.24258580925573

# %%
rides_feb = taxi[taxi[:,1] == 2,1]

# %%
print(rides_feb.shape[0])
# Out:
# 13333

# %%
tip_amt = taxi[taxi[:,-3] > 50, -3]
tip_amt.shape[0]
# Out:
# 16

# %%
print(taxi[taxi[:,6] == 2,6].shape[0])
# Out:
# 11832
